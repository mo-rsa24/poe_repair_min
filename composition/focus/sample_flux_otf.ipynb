# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torch

from peft import PeftModel

from src.controller import Controller
from src.flux import FluxControllerPipeline

# %%
pipe = FluxControllerPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-dev", 
    torch_dtype=torch.bfloat16
)

if getattr(pipe, "transformer", None):      pipe.transformer.requires_grad_(False)
if getattr(pipe, "vae", None):              pipe.vae.requires_grad_(False)
if getattr(pipe, "text_encoder", None):     pipe.text_encoder.requires_grad_(False)
if getattr(pipe, "text_encoder_2", None):   pipe.text_encoder_2.requires_grad_(False)
if getattr(pipe, "text_encoder_3", None):   pipe.text_encoder_3.requires_grad_(False)
print("Model loaded")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Model loaded

# %%
# ONLY NEEDED FOR SMALL VRAM
pipe.enable_sequential_cpu_offload()
pipe.transformer.enable_gradient_checkpointing()

from functools import partial
pipe.transformer.enable_gradient_checkpointing(
    gradient_checkpointing_func=partial(torch.utils.checkpoint.checkpoint, use_reentrant=False)
)

# %%
SEED = 5
STEPS = 25
GUIDANCE = 3.5
SIZE = 512
PROMPT = "A lion and a tiger resting side by side in a jungle clearing"

controller = Controller(
    t5_ids = [[2], [7, 8]],
    clip_ids = [[2], [5]],
    lambda_scale=4,
    heuristic="enmmdt_loss", # "conform", "focus", "attend_and_excite", "divide_and_bind"
    model="FLUX"
)

output_controller = pipe(
    PROMPT,
    num_inference_steps=STEPS,
    guidance_scale=GUIDANCE,
    height=SIZE,
    width=SIZE,
    max_sequence_length=256,
    generator=torch.Generator("cpu").manual_seed(SEED),
    controller=controller,
    num_images_per_prompt=1
).images[0]

output_controller
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 15
#       5 PROMPT = "A lion and a tiger resting side by side in a jungle clearing"
#       7 controller = Controller(
#       8     t5_ids = [[2], [7, 8]],
#       9     clip_ids = [[2], [5]],
#    (...)
#      12     model="FLUX"
#      13 )
# ---> 15 output_controller = pipe(
#      16     PROMPT,
#      17     num_inference_steps=STEPS,
#      18     guidance_scale=GUIDANCE,
#      19     height=SIZE,
#      20     width=SIZE,
#      21     max_sequence_length=256,
#      22     generator=torch.Generator("cpu").manual_seed(SEED),
#      23     controller=controller,
#      24     num_images_per_prompt=1
#      25 ).images[0]
#      27 output_controller
#
# File ~/PythonSemesterProject/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/temp/FOCUS/src/flux/pipeline.py:953, in FluxControllerPipeline.__call__(self, prompt, prompt_2, negative_prompt, negative_prompt_2, true_cfg_scale, height, width, num_inference_steps, sigmas, guidance_scale, num_images_per_prompt, generator, latents, prompt_embeds, pooled_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, negative_ip_adapter_image, negative_ip_adapter_image_embeds, negative_prompt_embeds, negative_pooled_prompt_embeds, output_type, return_dict, joint_attention_kwargs, callback_on_step_end, callback_on_step_end_tensor_inputs, max_sequence_length, controller)
#     939 noise_pred = self.transformer(
#     940     hidden_states=latents,
#     941     timestep=timestep / 1000,
#    (...)
#     948     return_dict=False,
#     949 )[0]
#     951 if controller is not None:
# --> 953     cost = controller.compute_cost()
#     954     cost.backward()
#     955     grad_cost = latents.grad
#
# File ~/temp/FOCUS/src/controller.py:199, in Controller.compute_cost(self)
#     196     loss_ls.append(self_cross_guidance_loss(emb, self.label_groups[idx], self_attn=selfA, lambda_cross=0.0))
#     198 elif self.heuristic == "enmmdt_loss":
# --> 199     loss_ls.append(enmmdt_loss(emb, self.label_groups[idx]))
#     201 else:
#     202     raise ValueError(f"Unknown heuristic: {self.heuristic}")
#
# UnboundLocalError: cannot access local variable 'loss' where it is not associated with a value

# %%
output_base = pipe(
    PROMPT,
    num_inference_steps=STEPS,
    guidance_scale=GUIDANCE,
    height=SIZE,
    width=SIZE,
    max_sequence_length=256,
    generator=torch.Generator("cpu").manual_seed(SEED),
    controller=None,
).images[0]

output_base
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
